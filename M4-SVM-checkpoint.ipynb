# %% [markdown]
# # SVC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Sales_Prediction_new.csv')

df.head()
# Out:
#   Product_Category   Price  Discount Customer_Segment  Marketing_Spend  \
# 0           Sports  932.80     35.82       Occasional          6780.38
# 1             Toys  569.48      3.60          Premium          6807.56
# 2       Home Decor  699.68      3.56          Premium          3793.91
# 3             Toys  923.27      0.61          Premium          9422.75
# 4             Toys  710.17     47.83          Premium          1756.83
#
#    Units_Sold
# 0          32
# 1          16
# 2          27
# 3          29
# 4          17

# %%
df.head()
# Out:
#   Product_Category   Price  Discount Customer_Segment  Marketing_Spend  \
# 0           Sports  932.80     35.82       Occasional          6780.38
# 1             Toys  569.48      3.60          Premium          6807.56
# 2       Home Decor  699.68      3.56          Premium          3793.91
# 3             Toys  923.27      0.61          Premium          9422.75
# 4             Toys  710.17     47.83          Premium          1756.83
#
#    Units_Sold
# 0          32
# 1          16
# 2          27
# 3          29
# 4          17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  4000 non-null   object
#  1   Price             4000 non-null   float64
#  2   Discount          4000 non-null   float64
#  3   Customer_Segment  4000 non-null   object
#  4   Marketing_Spend   4000 non-null   float64
#  5   Units_Sold        4000 non-null   int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 187.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  4000 non-null   object
#  1   Price             4000 non-null   float64
#  2   Discount          4000 non-null   float64
#  3   Customer_Segment  4000 non-null   object
#  4   Marketing_Spend   4000 non-null   float64
#  5   Units_Sold        4000 non-null   int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 187.6+ KB

# %%
df=df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Product_Category','Customer_Segment']

for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df.columns
# Out:
# Index(['Product_Category', 'Price', 'Discount', 'Customer_Segment',
#        'Marketing_Spend', 'Units_Sold'],
#       dtype='object')

# %%
df=df.drop_duplicates()

# %%
# Split the datasets into depended and independed variable
# X is independend variable (Input features)
x1 = df.drop(labels='Product_Category', axis=1)

# Y is dependend variable (Target variable)
y1 = df.loc[:,'Product_Category']

# %%
# This process execute to balanced the datasets features.
import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x1,y1)
print("OUR DATASET COUNT         : ", Counter(y1))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({0: 210, 3: 206, 4: 204, 2: 190, 1: 190})
# OVER SAMPLING DATA COUNT  :  Counter({3: 210, 4: 210, 2: 210, 1: 210, 0: 210})

# %%
# Split the datasets into two parts like trainng and testing variable.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, stratify=y)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  840
# NUMBER OF TEST DATASET      :  210
# TOTAL NUMBER OF DATASET    :  1050

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  840
# NUMBER OF TEST DATASET      :  210
# TOTAL NUMBER OF DATASET    :  1050

# %%
# Implement Adaboost classifier algorithm learning patterns
from sklearn.svm import SVC

# %%
ABC = SVC()
# Fit is the training function for this algorithm.
ABC.fit(x_train,y_train)
# Out:
# SVC()

# %%
# Predict is the test function for this algorithm
predicted = ABC.predict(x_test)

# %%
# Check classification report for this algorithm
from sklearn.metrics import classification_report
cr = classification_report(y_test,predicted)
print('THE CLASSIFICATION REPORT OF ExtraTreesClassifier:\n\n',cr)
# Out:
# THE CLASSIFICATION REPORT OF ExtraTreesClassifier:
#
#                precision    recall  f1-score   support
#
#            0       0.29      0.33      0.31        42
#            1       0.29      0.05      0.08        42
#            2       0.24      0.55      0.34        42
#            3       0.25      0.31      0.27        42
#            4       0.29      0.05      0.08        42
#
#     accuracy                           0.26       210
#    macro avg       0.27      0.26      0.22       210
# weighted avg       0.27      0.26      0.22       210

# %%
# Check the confusion matrix for this algorithms.
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
print('THE CONFUSION MATRIX SCORE OF SVC:\n\n\n',cm)
# Out:
# THE CONFUSION MATRIX SCORE OF SVC:
#
#
#  [[14  1 15 11  1]
#  [ 7  2 21 10  2]
#  [ 8  1 23 10  0]
#  [10  2 15 13  2]
#  [10  1 20  9  2]]

# %%
# Check the cross value score of this algorithm.
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(ABC, x, y, scoring='accuracy')
print('THE CROSS VALIDATION TEST RESULT OF ACCURACY :\n\n\n', accuracy*100)
# Out:
# THE CROSS VALIDATION TEST RESULT OF ACCURACY :
#
#
#  [23.80952381 21.42857143 21.9047619  20.95238095 24.76190476]

# %%
# Check the accuracy score of this algorithms.
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,predicted)
print("THE ACCURACY SCORE OF SVC IS :",a*100)
# Out:
# THE ACCURACY SCORE OF SVC IS : 25.71428571428571

# %%
# Check the hamming loss of this algorithm.
from sklearn.metrics import hamming_loss
hl = hamming_loss(y_test,predicted)
print("THE HAMMING LOSS OF SVC IS :",hl*100)
# Out:
# THE HAMMING LOSS OF SVC IS : 74.28571428571429

# %%
# Plot a Confusion matrix for this algorithms.
def plot_confusion_matrix(cm, title='THE CONFUSION MATRIX SCORE OF SVC\n\n', cmap=plt.cm.cool):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

cm1=confusion_matrix(y_test, predicted)
print('THE CONFUSION MATRIX SCORE OF SVC:\n\n')
print(cm)
plot_confusion_matrix(cm)
# Out:
# THE CONFUSION MATRIX SCORE OF SVC:
#
#
# [[14  1 15 11  1]
#  [ 7  2 21 10  2]
#  [ 8  1 23 10  0]
#  [10  2 15 13  2]
#  [10  1 20  9  2]]

# %%
# Plot the worm plot for this model.
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
